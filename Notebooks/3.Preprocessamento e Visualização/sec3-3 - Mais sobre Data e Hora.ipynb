# %% [markdown]
# # Mais Detalhes sobre Data e Hora
# Prof. Fernando Amaral

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../../Dados/AirPassengers.csv")
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
print(data.dtypes)
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
dateparse = lambda dates: pd.to_datetime(dates, format='%Y-%m')
data = pd.read_csv('../../Dados/AirPassengers.csv', parse_dates=['Month'], index_col='Month', date_parser=dateparse)
# Out:
# C:\Users\lucas.souza\AppData\Local\Temp\ipykernel_22552\2370306663.py:2: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_csv('../../Dados/AirPassengers.csv', parse_dates=['Month'], index_col='Month', date_parser=dateparse)

# %%
data.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
print (data.dtypes)
# Out:
# #Passengers    int64
# dtype: object

# %%
data.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
import matplotlib.pyplot as plt
#parametros de configuração
from matplotlib.pylab import rcParams
#15x6
rcParams['figure.figsize'] = 15, 6
#para impressão de datas
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
plt.plot(data)
plt.title("Pasageiros")
plt.show()
