# %% [markdown]
# # Componentes de uma Série Temporal
# Prof. Fernando Amaral

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from pandas import Series
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from datetime import datetime

# %%
dateparse = lambda dates: datetime.strptime(dates, '%Y-%m')
data = pd.read_csv('../../Dados/AirPassengers.csv', parse_dates=['Month'], index_col='Month', date_parser=dateparse)
# Out:
# C:\Users\lucas.souza\AppData\Local\Temp\ipykernel_12912\1947005139.py:2: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_csv('../../Dados/AirPassengers.csv', parse_dates=['Month'], index_col='Month', date_parser=dateparse)

# %%
data.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
plt.plot(data)
plt.title('Passageiros Internacionais Transportados', fontsize=24)
plt.ylabel('Passageiros')
plt.xlabel('Data')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
# Out:
# c:\Users\lucas.souza\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tools\tools.py:6: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.0)
#   import scipy.linalg

# %%
result = seasonal_decompose(data, model='multiplicative')

# %%
result.resid
# Out:
# Month
# 1949-01-01   NaN
# 1949-02-01   NaN
# 1949-03-01   NaN
# 1949-04-01   NaN
# 1949-05-01   NaN
#               ..
# 1960-08-01   NaN
# 1960-09-01   NaN
# 1960-10-01   NaN
# 1960-11-01   NaN
# 1960-12-01   NaN
# Name: resid, Length: 144, dtype: float64

# %%
result.plot()
plt.show()

# %%
result2 = seasonal_decompose(data, model='aditive')
result2.plot()
plt.show()
